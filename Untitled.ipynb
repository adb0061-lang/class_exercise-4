# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = gpd.read_file("C:/Users/abreden/AES_508/homework_2/us_eco_l3_state_boundaries")
df.plot()
# Out:
# <Axes: >
